# %%
import os

# Setting the environment variable for Hugging Face authentication
os.environ["HF_TOKEN"] = "hf_WFBwkTvnqjvKZsXoVhHkJmLhXlKzqjN"

# %%
from transformers import AutoTokenizer

# Loading the specific Google Gemma-3 tokenizer
# This model uses SentencePiece and is highly efficient for modern LLM tasks
tokenizer = AutoTokenizer.from_pretrained("openai-community/gpt2")
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
# Testing the tokenizer with a simple string
# This will output the Token IDs, Attention Mask, and other metadata
output = tokenizer("Hey There Prantik!")
print(f"Token IDs: {output['input_ids']}")

# New: Convert those IDs back to words to see the "slices"
tokens_as_words = [tokenizer.decode([tid]) for tid in output['input_ids']]
print(f"Tokens: {tokens_as_words}")
# Out:
# {'input_ids': [10814, 1318, 1736, 415, 1134, 0], 'attention_mask': [1, 1, 1, 1, 1, 1]}
